# %% [markdown]
# **Stack**
#
# LIF0 - Last In First Out
#
# **Push** --> recursiveMethod(4) > recursiveMethod(3) > recursiveMethod(2) > recursiveMethod(1)
#
# -------------------------
# |4. recursiveMethod(1)  |
# -------------------------
#
# |3. recursiveMethod(2)  |
# -------------------------
#
# |2. recursiveMethod(3)  |
# -------------------------
#
# |1. recursiveMethod(4)  |
# -------------------------
#
# As 0 is less than 1 no need to store recursiveMethod(0) in stack. It will start executing the output.
#
# It will be printed "Exit condition Satisfied. Exited."
#
# start poping
#
# **Pop**
#
# recursiveMethod(4) > recursiveMethod(3) > recursiveMethod(2)
# recursiveMethod(4) > recursiveMethod(3)
# recursiveMethod(4)
# All function poped out. Empty stack.
#
# -------------------------
# |_______________________|
# -------------------------
#
# |3. recursiveMethod(2)  |
# -------------------------
#
# |2. recursiveMethod(3)  |
# -------------------------
#
# |1. recursiveMethod(4)  |
# -------------------------
#
# -------------------------
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# |2. recursiveMethod(3)  |
# -------------------------
#
# |1. recursiveMethod(4)  |
# -------------------------
#
# -------------------------
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# |1. recursiveMethod(4)  |
# -------------------------
#
# -------------------------
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# |_______________________|
# -------------------------
#
# **Final output:**
# Exit condition Satisfied. Exited.
# 1
# 2
# 3
# 4

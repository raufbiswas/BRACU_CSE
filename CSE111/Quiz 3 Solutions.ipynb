# %% [markdown]
# **SET B (Question 1)**

# %%
class ABCHospital:
  surgery_patient = 0    #0.5
  neurology_patient = 0   #0.5
  pediatric_patient = 0   # 0.5

  def __init__(self, name, age, contact, *symptoms):  #1
    self.name = name
    self.age = age
    self.__contact = contact    #0.5
    self.symptoms = []
    self.floor = 0
    for a in symptoms:
      self.symptoms.append(a)     #0.5
  
  def admitInHospital(self, dept):
    self.dept = dept
    if dept == 'Neurology':
      ABCHospital.neurology_patient+=1    #0.5
      self.floor = 2     #0.5
    elif dept == 'Surgery':
      ABCHospital.surgery_patient+=1      #0.5
      self.floor = 4  #0.5
    elif dept == 'Pediatric':
      ABCHospital.pediatric_patient+=1     #0.5
      self.floor = 3     #0.5
    print(f'Surgery: {ABCHospital.surgery_patient}, Pediatric: {ABCHospital.pediatric_patient}, Neurology: {ABCHospital.neurology_patient}')   #1

  @classmethod    #1
  def initializePatient(cls,name, age, contact, sym):  #1
    return cls(name, age, contact, sym)   #1
      
  def set_contact(self, c):     #0.5
    self.__contact = c         #0.5
    print('Contact Updated!!')    #0.5
  
  def get_contact(self):     #1
    return self.__contact

  def printInfo(self):   #0.5
    print(f'Patient Name: {self.name}\nAge:{self.age}\nContact: {self.__contact}\nFloor Number: {self.floor}\nSymptoms: {self.symptoms}')  #0.5

    

    
h1 = ABCHospital('James', 35, 88294, 'Common Cold', 'Ear pain', 'Bronchitis')
print('----------------------------------------')
h1.admitInHospital('Pediatric')
print('#######################################')
h1.printInfo()
h2 = ABCHospital.initializePatient('Sirajee', 81, 98753, 'Nausea')
print('----------------------------------------')
h2.admitInHospital('Surgery')
print('#######################################')
h2.printInfo()
h2.set_contact(89765)
print(f"{h2.name}'s updated contact number: {h2.get_contact()}")
h3 = ABCHospital('Harry', 43, 567390, 'Restlessness', 'Vomiting')
print('----------------------------------------')
h3.admitInHospital('Surgery')
print('#######################################')
h3.printInfo()
print('----------------------------------------')
# Out:
# ----------------------------------------
# Surgery: 0, Pediatric: 1, Neurology: 0
# #######################################
# Patient Name: James
# Age:35
# Contact: 88294
# Floor Number: 3
# Symptoms: ['Common Cold', 'Ear pain', 'Bronchitis']
# ----------------------------------------
# Surgery: 1, Pediatric: 1, Neurology: 0
# #######################################
# Patient Name: Sirajee
# Age:81
# Contact: 98753
# Floor Number: 4
# Symptoms: ['Nausea']
# Contact Updated!!
# Sirajee's updated contact number: 89765
# ----------------------------------------
# Surgery: 2, Pediatric: 1, Neurology: 0
# #######################################
# Patient Name: Harry
# Age:43
# Contact: 567390
# Floor Number: 4
# Symptoms: ['Restlessness', 'Vomiting']
# ----------------------------------------

# %%
class A:
    temp = 2
    def __init__(self, b = None):
        self.x, self.y, self.temp, self.sum = -2, 4, 7, 1
        if b != None:
            self.y = self.temp + 1
            b.sum = 5 + self.temp + 3
            self.temp -= 3
            print(self.y, self.temp, b.sum)
        else:
            self.sum+=2
            A.temp = self.x
    def methodA(self, m, n):
        x = 7
        self.y = self.y + m + (self.temp)
        self.temp += A.temp + n
        x = x + 5 + m
        self.sum = self.sum + x + self.y
        print(self.temp, self.y, self.sum)



    
a1 = A()
a2 = A(a1)
a1.methodA(4,2)
# Out:
# 8 4 15
# 7 15 46

# %% [markdown]
# **SET A (Question 1)**

# %%
class University:
  cse_student = 0     #0.5
  bba_student = 0     #0.5
  eee_student = 0     #0.5

  def __init__(self, name, id, gender, *courses):   #1
    self.name = name
    self.__id = id      #0.5
    self.gender = gender
    self.courses = []
    self.loc = ''
    for a in courses:
      self.courses.append(a)   #0.5
  
  def enrollInUni(self, dept):
    self.dept = dept
    if dept == 'CSE':
      University.cse_student+=1    #0.5
      self.loc = 'UB806'        #0.5
    elif dept == 'BBA':
      University.bba_student+=1      #0.5
      self.loc = 'UB209'            #0.5
    elif dept == 'EEE':
      University.eee_student+=1        #0.5
      self.loc = 'UB502'              #0.5
    print(f'BBA_student: {University.bba_student}, EEE_student: {University.eee_student}, CSE_student: {University.cse_student}')    #1

  @classmethod    #1
  def initializeStudent(cls,name, id, gender, courses):    #1
    return cls(name, id, gender, courses)     #1

  def set_id(self, id):      #0.5
    self.__id = id     #0.5
    print("The student's id is updated!!")     #0.5
  
  def get_id(self):     #1
    return self.__id

  def printInfo(self):    #1
    print(f'Student Name: {self.name}\nID:{self.__id}\nGender: {self.gender}\nLocation: {self.loc}\nCourses: {tuple(self.courses)}')

    

    
std1 = University('Harry', 181006, 'Male', 'ENG101', 'MAT110')
print('----------------------------------------')
std1.enrollInUni('CSE')
print('#######################################')
std1.printInfo()
std2 = University.initializeStudent('Bob', 191005, 'Male', 'ENG091')
print('----------------------------------------')
std2.enrollInUni('BBA')
print('#######################################')
std2.printInfo()
std2.set_id(181005)
print(f"{std2.name}'s updated id: {std2.get_id()}")
std3 = University('Jennifer', 181009, 'CSE', 'ENG102', 'MAT092', 'BUS101')
print('----------------------------------------')
std3.enrollInUni('CSE')
print('#######################################')
std3.printInfo()
print('----------------------------------------')
# Out:
# ----------------------------------------
# BBA_student: 0, EEE_student: 0, CSE_student: 1
# #######################################
# Student Name: Harry
# ID:181006
# Gender: Male
# Location: UB806
# Courses: ('ENG101', 'MAT110')
# ----------------------------------------
# BBA_student: 1, EEE_student: 0, CSE_student: 1
# #######################################
# Student Name: Bob
# ID:191005
# Gender: Male
# Location: UB209
# Courses: ('ENG091',)
# The student's id is updated!!
# Bob's updated id: 181005
# ----------------------------------------
# BBA_student: 1, EEE_student: 0, CSE_student: 2
# #######################################
# Student Name: Jennifer
# ID:181009
# Gender: CSE
# Location: UB806
# Courses: ('ENG102', 'MAT092', 'BUS101')
# ----------------------------------------

# %%
class A:

    temp = 4
    def __init__(self, b = None):
        self.x, self.y, self.temp, self.sum = 4, -3, 2, 6
 
        if b != None:
            self.y = self.temp + 1
            b.sum = 5 + self.temp + 3
            self.temp -= 3
            print(self.y, self.temp, b.sum)
        else:
            self.sum+=2
            A.temp = self.x
    def methodA(self, m, n):
        x = 11
        self.y = self.y + m + (self.temp)
        self.temp += A.temp + n
        x = x + 7 + m
        self.sum = self.sum + x + self.y
        print(self.temp, self.y, self.sum)

    
a1 = A()
a2 = A(a1)
a1.methodA(-1,5)
# Out:
# 3 -1 10
# 11 -2 25

# %%
number = int(input("Enter a number: "))
if number>10:
 print("The number is greater than 10")
 print('Ami boro')
else:
  print("The number is either less than 10 or equal")

#print('Ami baire amake mero na')
# Out:
# Enter a number: 5
# The number is either less than 10 or equal

# %%
number = input("Enter a number: ")
number = int(number)

if (number > 50):
  print('The number is  greater than 50')  
else:
  print('The number is not greater than 50')
# Out:
# Enter a number: 50
# The number is not greater than 50

# %%
4%3
# Out:
# 1

# %%
weather = 'rainy'
#rainy

if weather == 'sunny':
  print("I'll play cricket")
else:
  print("I'll play indoor games")
# Out:
# I'll play indoor games

# %%
number = input("Please enter a number: ")
number = int(number)
if number % 2 != 0:
  print('This is an odd number')
else:
  print('This is an even number')
# Out:
# Please enter a number: 4
# This is an even number

# %%
number = int(input("Enter a number: "))
if number > 10:
  print('Hello') 
  print('The number is greater than 10')
elif number < 20:
  print('The number is less than 10')
else:
  print('The number is equal to 10')
# Out:
# Enter a number: 23
# The number is greater than 10

# %%
name = input('Enter your name: ')
number = int(input('Enter a number: '))

if number > 10:
  print('The number is greater than 10')
elif number> 10 and name == 'nazia':
  print('The number is greater than 10 and name is nazia')
elif number < 10 and name == 'nazia':
  print('The number is less than 10 and name is nazia')
else:
  print('The number is less than or equal to 10')
# Out:
# Enter your name: naz
# Enter a number: 12
# The number is greater than 10

# %%
number = 6
if number>5:
  print('kkg')
elif number < 10:
  print('fdg')
elif number < 100:
  print('jf')
else:
  print('Finish')

# %%
print('My name is\n'+ str(23))
# Out:
# My name is
# 23

# %%
txt = "For only {price:.4f} dollars!"
print(txt.format(price = 49))
# Out:
# For only 49.0000 dollars!

# %%
hour = int(input("Enter the time: "))
if hour >=0 and hour<= 23:
  if hour >= 4 and hour <= 6:
    print('Breakfast')
  elif (hour>= 12 and hour<=13) and (hour > 40 or hour < 50):
    print('lunch')
  elif hour >= 16 and hour <= 17:
    print('Snacks')
  elif hour >=19 and hour <=20:
    print('Dinner')
  else:
    print('Patience is virtue')
else:
  print("Wrong time")
# Out:
# Enter the time: 23
# Patience is virtue

# %%
line = input()
print(line[0])
# Out:
# My name is Nazia. ami vat khai
# M

# %%
number = int(input())
if number % 2 == 0:
  if number > 6:
    print()
else:
  print('')

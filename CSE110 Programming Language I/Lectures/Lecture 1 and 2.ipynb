# %%
print(len(['']))
# Out:
# 1

# %% [markdown]
# **Variables**

# %% [markdown]
# * Variables must have a meaningful name
# * Variable name must start with small letter
# * Variable names can have letters (A-Z),(a-z), digits (0-9) and underscores ‘_’
# * Use ‘_’ between words in a variable
# * Case sensitive

# %%
name = 'Bob'

# %%
student_1 = 'Max'
student2 = 'Bob'

# %%
student_ID = 18101006

# %%
full_name = 'Nazia Iqbal'

# %% [markdown]
# * Variable names can not have whitespaces and special characters (+,-,!,@,$,#,%)

# %%
$name = 'Bob'      #This is an inappropriate variable name

# %%
value- = 10        #This is an inappropriate variable name
# Out:
#   File "<ipython-input-4-b808ec162369>", line 1
#     value- = 10        #This is an inappropriate variable name
#            ^
# SyntaxError: invalid syntax

# %%
na+me = 'Momo'     #This is an inappropriate variable name
# Out:
#   File "<ipython-input-5-176cf942accb>", line 1
#     na+me = 'Momo'     #This is an inappropriate variable name
#                                                               ^
# SyntaxError: can't assign to operator

# %% [markdown]
# **Data Type**
#
# * We use variables to store values and every value in python has a data type.
# * type() function

# %%
name = 'Bob'
number = 10
value = True
my_new_list = [1,2,3]
my_new_touple = (1,'a','Z')
my_new_dictionary = {1: 'bob', 2: 'Max'}

print(type(name))
# Out:
# <class 'str'>

# %%
print(type(number))
# Out:
# <class 'int'>

# %%
print(type(value))
# Out:
# <class 'bool'>

# %%
print(type(my_new_list))
# Out:
# <class 'list'>

# %% [markdown]
# **Input and Output Function**

# %%
name = input('Please Enter your Name: ')
# Out:
# Please Enter your Name: Nazia

# %%
print(name)
# Out:
# Nazia

# %%
x = 10
y = 10.0
print(x is y)
# Out:
# False

# %%
x = 10
y = '10'
print(x is y)
# Out:
# False

# %%
x = 'python'
y = 'Python'
print(x is not y)
# Out:
# True

# %%
x = 10
y = 15
z = 18

#print(x == 10 and y > 13)
#print(x == 10 and y < 13)
#print(x > 10 and y == 15 and z < 17)

#Eikhane ami or operator er kaj dekhchi. 
print(x > 5 or y == 10) #Amar naam nazia
# print(True or True)
# print(True or False)
# print(False or False)

# print(not(True))
# print(not(False))
# print(not(z == 18))
# Out:
# True

# %%
name = input("Enter your name: ")
print('The value of name is', name)
# Out:
# Enter your name: nazia
# The value of name is nazia

# %%
print(len('5.0'))
# Out:
# 3

# %% [markdown]
# **String is a sequence of characters in a program**
#
#
# *   It starts and ends with a quotation mark (" ") or apotrophe (' ')
# *   If it starts with (") then it must ends with (")
# *   You can't starts a string with (") & ends with (') and vise versa

# %%
my_string1 = "Hello"
my_string2 = 'Hello'
my_string3 = "This is a valid string" 

#------Invalid string example-------
#my_string4 = 'Hello
#my_string5 = 'Hello"
#my_string6 = "Hello'

# %% [markdown]
# What if there is a single quote or double quote inside a String?

# %%
#str1 = 'Hello my name is 'Nazia' and this is an invalid string'
#str2 = "I loved the movie "Big Hero 6" very much"
str3 = "Hello my name is 'Nazia' and this is a valid string"
print(str3)
str4 = 'I loved the movie "Big Hero 6" "I like it" very much'
print(str4)
# Out:
# Hello my name is 'Nazia' and this is a valid string
# I loved the movie "Big Hero 6" "I like it" very much

# %% [markdown]
# **String Examples**

# %%
# A single character is also a string
s1 = 'a'
s2 = "A"

#Strings are case sensitive

s3 = "I"
s4 = "i"
print(s3 == s4)

#Space is also a string

s4 = " "
s6 = ' '

#Empty string example

emp_string1 = ''
emp_string2 = ""
# Out:
# False

# %% [markdown]
# **Multi-line Strings**
# *   You can't write multi-line strings using (" ") or (' ')
# *   Multi-line strings starts and ends with triple quotations (''' ''')

# %%
#Invalid multi=line string

#my_str = "I love
#python so
#much"

#Valid multi-line string

my_str2 = 'I love\n python so \n much'
print(my_str2)
# Out:
# I love
#  python so
#  much

# %% [markdown]
# **len() funtion**
#
#
# *   len(string) returns number of the length of the string given as argument
# *   It means len(string) returns the number of characters in the given string

# %%
length1 = len("Hello     i")
print(length1)

length2 = len("My name is")
print(length2)
# Out:
# 11
# 10

# %% [markdown]
# **String Indexes**
#
#
# *   Indexes starts from 0 and indexes must be integer
# *   Indexes can also be negative
# ![Screen Shot 6-16-2022 at 1.38 PM.png](data:image/png;base64,...)

# %%
my_string = 'Python is awesome '
print('1st character is', my_string[0])
print('2nd character is', my_string[1])
print('3rd character is', my_string[2])
print('last character is', my_string[-1])
#print(my_string[19])
# Out:
# 1st character is P
# 2nd character is y
# 3rd character is t
# last character is
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-3dd3cf0c5161> in <module>()
#       4 print('3rd character is', my_string[2])
#       5 print('last character is', my_string[-1])
# ----> 6 print(my_string[19])
#
# IndexError: string index out of range

# %% [markdown]
# **String Mutability**
#
#
# *   Strings are immutable
# *   Once a string is created the characters on it can't be changed or deleted

# %%
sentence = 'I love CSE110'
#sentence[0] = 'W'

#However the can change the entire string

my_sentence = 'I am Baymax'
#print(my_sentence)
my_sentence = 'I am superman'
del my_sentence
#print(my_sentence)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-af8e94e70912> in <module>()
#       8 my_sentence = 'I am superman'
#       9 del my_sentence
# ---> 10 print(my_sentence)
#
# NameError: name 'my_sentence' is not defined

# %% [markdown]
# **Iterating over String**
#
# We can use loops to iterate a string

# %%
s = 'Hello World'
#Using while loop
index = 0
while index<len(s):
  print(s[index])
  index+=1

#Using for loop
for char in s:
 print(char)
# Out:
# H
# e
# l
# l
# o
#
# W
# o
# r
# l
# d

# %% [markdown]
# **String Operations (Concatenation)**
#
#
# *   '+' operator is used to merge/concat two strings
# *   '+' operator doesn't add space between two strings automatically

# %%
s1 = 'I love python.'
s2 = 'It is awesome.'
s3 = 'Hello section 14'
print(s1+s2)
print(s1+' '+s2)
print(s1+' '+s2+' '+s3)
print('My'+'name'+'is'+'"'+ 'Nazia'+'"')
print('My'+ ' '+'name'+' '+'is'+' '+ '"'+ 'Nazia'+'"')
# Out:
# I love python.It is awesome.
# I love python. It is awesome.
# I love python. It is awesome. Hello section 14
# Mynameis"Nazia"
# My name is "Nazia"

# %% [markdown]
# **String Operations (Deletion)**
#
#
# *   ‘del’ keyword to unbind reference to a String.
# *   Cannot delete a character from a String (Immutability)

# %%
movie = 'Spider-man'
print(movie)
del movie
#print(movie)

#-----Can not delete a character from a string-----
movie_name = 'Big Hero 6'
del movie_name[1]
# Out:
# Spider-man
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-93984db863a5> in <module>()
#       6 #-----Can not delete a character from a string-----
#       7 movie_name = 'Big Hero 6'
# ----> 8 del movie_name[1]
#
# TypeError: 'str' object doesn't support item deletion

# %% [markdown]
# **String Operations (Repetition)**
#
#
# *   ‘*’ operator to repeat a String multiple times.
# *  We can also use loops

# %%
s = 'I love Baymax '
print(4 * s)
print(4*'Hi\n')
for x in range(4):
#  print("Hi")
# Out:
# I love Baymax I love Baymax I love Baymax I love Baymax
# Hi
# Hi
# Hi
# Hi

# %% [markdown]
# **String Operations (Slicing)**
#
# Syntax:
#
# String[start: stop: step]
#
# *   start: From which index to start, inclusive. If not set, default value is 0
# *   stop: At which index to stop slicing, exclusive. If not set, default value is last index of the String
# *   step: Optional. How many step to take. If not set, default value is 1.

# %%
s = 'I love Spider-man movie'
# print(s[2:4:1])
# print(s[11:16:2])
# print(s[5:])
# print(s[:])
#print(s[len(s): :])
print(s[5:1:-1])
print(s[3::2])

# %% [markdown]
# **Checking String Membership**
#
#
# *   Use ‘in’ keyword to find whether a String is present inside another String or not.
# *   Syntax: String1 in String2
#
# If String1 is present inside String2, the result will be True ; Otherwise the result will be False.

# %%
my_str1 = 'Hello world'
my_str2 = 'rd'
print(my_str2 in my_str1)

print('class' not in 'I class love python')

# if my_str1 in my_str2:
#   print('Not Found')
# else:
#   print("Found")
# Out:
# False

# %% [markdown]
# **Escape Sequence (\\)**
#
# If you have some special character inside your String that might confuse the interpreter, you can use escape
# sequence to clarify.

# %%
mv = 'I love the movie "Big Hero 6"'
mv2 = 'I love the movie \'Big Hero 6\''
print(mv2)
# Out:
# I love the movie 'Big Hero 6'

# %% [markdown]
# **String Formatting**
#
#
# *   Use format() function to format Strings.

# %%
s = "Hello {}, I am {}.".format("class", "Nazia")
print(s)
s = "Hello {0}, I am {1}.".format("Bob", "Nazia")
#print(s)
s = "Hello {1}, I am {0}.".format("Bob", "Nazia")
#print(s)
#s = "Hello {1}, I am {2}.".format("class", "Nazia")
#print(s)
# Out:
# Hello class, I am Nazia.

# %% [markdown]
# **ASCII**
# *   Machines do not understand characters or decimals.
# *   Only binary numbers (0s and 1s)
# *   Every character is converted to an integer number called the “ASCII code”.
# *   The ASCII code is converted to binary numbers.
# *   ASCII (American Standard Code for Information Interchange) is a code for representing any character typed using keyboards as numbers, assigned from 0 to 127.
# *   You can convert a character to its corresponding ASCII value using **ord(character)** function and convert number to its corresponding character using **chr(int)** function.

# %%
## Chatacter to ASCII value conversion
#print(ord('A'))
#print(ord('Z'))
#print(ord('a'))
#print(ord('z'))
print(ord('@'))

## ASCII value to Character conversion

#print(chr(65))
#print(chr(90))
#print(chr(97))
#print(chr(122))
# Out:
# 64

# %% [markdown]
# **String Functions**
#
# String Functions do not change the string itself, instead they return a modified string
#
# Syntax: string_name.function_name()
#
# 1.   **lower()** returns a copy of the string with all lower case letters.
# 2.   **upper()** returns a copy of the string with all upper case letters.
# 1.   **strip()** returns a copy of the string with all whitespace removed before and after the string.
# 2.   **count(substring)** returns total occurrence of substring in the main string.
# 2.   **startswith(substring)** returns True if the string starts with given substring; Otherwise returns False
# 1.   **endswith(substring)** returns True if the string ends with given substring; Otherwise returns False.
# 2.   **find(substring)** returns the index of first occurrence of substring in the main string.
# 1.   **replace(oldstring, newstring)** replaces every instance of the oldstring with newstring.

# %%
sample = '   My NaMe    IS Aalif   '
#print(sample.lower())
print(sample)
###--------------------------###
#print(sample.upper())
###-------------------------###
#print(sample.strip())
###------------------------###
#print(sample.count('P'))
#print(sample.count('Z'))
###----------------------###
#print(sample.startswith('My'))

#print(sample.startswith(' '))
###----------------------###
print(sample.endswith('lif   '))
print(sample.endswith('p'))
###----------------------###
#print(sample.find('a'))
#print(sample.find(' '))
#print(sample.find('Aalif'))
###----------------------###
#print(sample.replace('p', 'Hi'))
#print(sample.replace(' ', "ZZZ"))
# Out:
#    My NaMe    IS Aalif
# True
# False

# %%
s = 'mY name'
s1 = s.endswith('ame')
print(s1)
# Out:
# True

# %% [markdown]
# **dir() Function**
#
# Use dir(String) to see all the methods in String class.
#
# Run this instruction: dir('Hello')

# %%
dir("1")
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# Write a Python program that will ask the user to input a string (containing exactly one word). Then your program should print subsequent substrings of the given string as shown in the examples below.
#
# =====================================================================
#
# Sample Input 1:
#
# BANGLA
#
# Sample Output 1:
#
# B
#
# BA
#
# BAN
#
# BANG
#
# BANGL
#
# BANGLA
#
#
# Explanation: The length of the string is 6 so there are 6 lines where in each line a substring of the input string, of length equal to the line number is printed i.e. substring with only the letter "B" printed in the first line, substring "BA" of length 2 printed in the 2nd line, "BAN" length of which is 3 being printed in the 3rd line and so on.
#
# =====================================================================
#
# Sample Input 2:
#
# DREAM
#
# Sample Output 2:
#
# D
#
# DR
#
# DRE
#
# DREA
#
# DREAM
#
#
# Explanation: Simply, no of lines = length of the input string and no of letters in each line = line number.
#
# =====================================================================

# %%
my_input = input("Enter a string of one word: ")
s = ''
for char in my_input:
  s += char
  print(s, end='')
  print()
# Out:
# Enter a string of one word: abc
# a
# ab
# abc

# %%
word = input()
for a in range(0,len(word)):
  print(word[a])
# Out:
# abcd
# a
# b
# c
# d

# %%
word = input()
for a in word:
  print(a)
# Out:
# abcd
# a
# b
# c
# d

# %%
str_value = input() 
for a in range(len(str_value)-1,-1,-1):
  print(str_value[a], end ='')

str_value = input() 
for a in range(-1,-len(str_value)-1,-1):
  print(str_value[a], end ='')
# Out:
# CSE110
# 011ESC

# %%
print('Hi'*3)
# Out:
# HiHiHi

# %%
print(ord('c'))
print(chr(99))
# Out:
# 99
# c

# %% [markdown]
# **Task 1**

# %%
value = input("Enter a string: ")
for element in  range(len(value)-1, -1, -1):
  print(value[element], end ='')
# Out:
# Enter a string: nazia
# aizan

# %%
my_string = input()
index = int(input())
print(my_string[index: :-1] + my_string[index+1: :1])
# Out:
# 12345
# 2
# 32145

# %%
value = input()
for element in value:
  print(element, ':', ord(element))
# Out:
# Programming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %%
value = 'beer'
print(value[0:-2:1])
# Out:
# be

# %%
name = 'stronger'
print(name[0:-2:1])
# Out:
# strong

# %%
value = input() #CSE110
for a in range(len(value)-1, -1, -1):
  print(value[a], end ='')
# Out:
# CSE110
# 011ESC

# %%
input_value = input() #00101
counter = 0

for character in input_value:
  if character == '0' or character == '1':
    counter +=1

if counter == len(input_value)
  print('binary')
else:
  print('not a binary')
# Out:
# 12345
# 2
# 32145

# %%
value = input() #bangla
for character in value:
  print(character, ':', ord(character))
# Out:
# Programming
# P : 80
# r : 114
# o : 111
# g : 103
# r : 114
# a : 97
# m : 109
# m : 109
# i : 105
# n : 110
# g : 103

# %%
value = input()
print(value[0:len(value)-2:1])
# Out:
# stronger
# strong

# %%
value = input()
print(value[::-1])
# Out:
# SAKIF
# FIKAS

# %%
value = 'Stronger'
print(value[0:len(value)-2:1]+'est')
# Out:
# Strongest

# %%
s = 'CSE110'
print(s[:6:-1])

# %%
print(14//7)
# Out:
# 2

# %%
x = input()
for a in range(len(x)):
  print(x[a], 'is in index:', a)
# Out:
# World
# W is in index: 0
# o is in index: 1
# r is in index: 2
# l is in index: 3
# d is in index: 4

# %%
sum = 0
print(not 1)
print(not 2)
print(not 3)
print(not 0)
print(not -1)
# Out:
# False
# False
# False
# True
# False

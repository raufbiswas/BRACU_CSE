# %%
def func_name(x):
  new = []
  for i in x:
    if new.count(i) <2:
      new.append(i)

my = [1,2,2,2, 3,4,5,5,5,5,2,4,67,7,66]
func_name(my)

# %% [markdown]
# **TASK 14**

# %%
sum = 0
number = int(input())
print('Divisors: ')
for div in range(1,number):
  if number%div == 0:
    print(div, end =' ')
    sum = sum + div
print()
if sum == number:
  print(number, 'is a perfect number')
else:
  print(number, 'is not a perfect number')
# Out:
# 33
# Divisors:
# 1 3 11
# 33 is not a perfect number

# %%
6%1 == 0
6%2 == 0
6%3 == 0
6%4
6%5

# %% [markdown]
# **TASK 15**

# %%
num = int(input())
div_count = 0
for divisors in range(1, num+1):
  if num%divisors == 0:
    div_count+=1

print('Ei number er total divisors:', div_count)

if div_count == 2:
  print(num, 'is a prime number')
else:
  print(num,'is not a prime number')
# Out:
# 11
# Ei number er total divisors: 2
# 11 is a prime number

# %% [markdown]
# **TASK 16**

# %%
max = -9999999099999999
min = 99999999999999999 
sum = 0
avg = 0
quantity = int(input())
for value in range(quantity):
  number = int(input())
  sum = sum + number
  if number<min:
    min = number
  if number>max:
    max = number

print('Minimun is:',min)
print('Maximum:', max)
print('Average', sum/quantity)

# 10 20 30 40
# Out:
# 3
# 99999999
# 999999999
# 9999999999
# Minimun is: 999999
# Maximum: 9999999999
# Average 3699999999.0

# %%
n = int(input())
for row in range(1,n+1):
  for col in range(1,row+1):
    print(col, end='')
  print()
# Out:
# 5
# 1
# 12
# 123
# 1234
# 12345

# %%
for a in range(18,64,9):
  if a%2 != 0:
    print(a*-1, end = ' ')
  else:
    print(a, end =' ')
# Out:
# 18 -27 36 -45 54 -63

# %% [markdown]
# **TASK 12**

# %%
number = int(input())
new_number = number
digit_count = 0
while number!=0:
 number = number // 10
 digit_count+=1

print('Total digit', digit_count)

print('Akhon number er value:', number)

power = 10 ** (digit_count-1)

while new_number!=0:
   digit =  new_number // power
   new_number  = new_number % power
   power = power // 10
   print(digit, end = ' ')
# Out:
# 890
# Total digit 3
# Akhon number er value: 0
# 8 9

# %%
print(34567//10000)
print(4567//1000)
print(567//100)
print(60//10)
print(0//1)
# Out:
# 3
# 4
# 5
# 6
# 7

# %%
s = 'stronger' 

if len(s)>3 and s[....]=='er':
  print(s[.....]+'est')
elif len(s)>3:
  print(s[....]+'er')

# %%
if s[....] == 'est':
  print(s)
elif s[....] == 'er':
  print(s[....]+'est')
elif len(s)>3:
  print(s[...]+'er')

# %%
value = input()
new_upper = ''
for character in range(......):
  value[character] != value[character+1]:
  concat korbo

for a in upper:
  if ord(a)>= 65 and ord(a)<=90:
    new_upper+=a
  else:
    new_upper += chr(ord(a)-32)

# %%
s = 'acbd, efg'
for a in range(len(s)):
  if s[a] ==',':
    


value = 'acbd'
value2 = 'efg'
duita for loop
ekta cholbe value porjonto
arekta cholbe value2 porjonto
the new ekta variable a value and value2 er character gula concat korbo

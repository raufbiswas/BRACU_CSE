# %% [markdown]
# **List**
#
#
# * List is a sequence of values called items or elements.
#
# * The elements can be of any data type.
#
# * Each value has a location (an index).
#
# * Indexes range from 0 to n-1 where n is the length of the list.
#
# * List is mutable, meaning, their elements can be changed.
#
# * Values are enclosed in [], myList = [1, 2, 3].

# %% [markdown]
# **Creating a List**
#
# A list is created by placing all the elements inside a square bracket [ ], separated by commas.
#
# It can have any number of items and they may be of different types (integer, float, string etc.).

# %%
my_list = [] # This is an empty list

my_list2 = [1,2,3,4] # List of integers

my_list2 = [1,'Ami ekta list', 2, '', True, 'Ei j true ekta boolean type value'] # List of values of Multiple datatypes

#Nested list
my_list = [1,2,['Ami',3,3.4,True],'Hello',[4,5,6]]

# %% [markdown]
# **List length – len() function**

# %%
my_list = [3,[],6,'Hi',8]
len(my_list)
print(my_list[1])
# Out:
# []

# %% [markdown]
# **Indexing of List**
#
# Just like strings, list can also be accessed using indexing method.
#
# * Range: Index starts at 0 and ends at n-1.
#
# * Type: Index must be an integer.
#
# * Index out of range will give IndexError. Different type will give type error.
#
# * Two indexing technique: Positive and Negative

# %%
input = [2,3,4.5,['Final',2,True, [5,8,9]], 'mid']
print(input[1])
print(input[-1])
print(input[3])
#print(input[4.0])
#print(input[3][0:3:2])
print(input[3][3][2])
#print(input[3][3][-2])
# Out:
# 3
# mid
# ['Final', 2, True, [5, 8, 9]]
# 9

# %% [markdown]
# **List Mutability**
#
# * Lists are mutable (changeable)
#
# * Unlike Strings items in list can easily be changed:
#
# * Can easily change an existing element
#
# * Can easily append/add new elements
#
# * Can easily delete/remove elements

# %%
color = ['Red', 'Blue']
color.append('YelloW')
print(color)
# Out:
# ['Red', 'Blue', 'YelloW']

# %%
# Example:

players_list = ['Ronaldo', 'Messi', 'Neymar', 'Bale']

print(players_list)


#print(players_list[2])


players_list[2] = 'Nazia' #Neymar is replaced by Mbappe

print(players_list)
# Out:
# ['Ronaldo', 'Messi', 'Neymar', 'Bale']
# ['Ronaldo', 'Messi', 'Nazia', 'Bale']

# %% [markdown]
# **Add items to a list**
#
# * append(value) - to add one item at the end of the list
# * extend([values]) - to add several items to a list once at the end
# * insert(location, value) - to add one item to a list at the desired index location

# %%
a = [1,2,3]
a.append(5)
print(a)
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# **append(value)**

# %%
players_list = ['Ronaldo', 'Messi', 'Neymar', 'Bale']
players_list.append(1)
print(players_list)
s = players_list.append('Ramos')
print(players_list)
# Out:
# ['Ronaldo', 'Messi', 'Neymar', 'Bale', 1]
# ['Ronaldo', 'Messi', 'Neymar', 'Bale', 1, 'Ramos']

# %% [markdown]
# **extend([values])**

# %%
cars = ['Bmw', 'Audi', 'Porsche']
cars.extend(['hwllo',2,4,6,7])
print(cars)
# Out:
# ['Bmw', 'Audi', 'Porsche', 'hwllo', 2, 4, 6, 7]

# %% [markdown]
# **insert(index,value)**

# %%
cars = ['Bmw', 'Audi', 'Porsche', [1,2]]
cars.insert(-5,'H')
print(cars)
# cars.insert(2, 'Hello')
# print(cars)
# print(cars.index('Hello'))
# s = ''
# s2 = ' '
# print(len(s))
# print(len(s2))
# Out:
# ['H', 'Bmw', 'Audi', 'Porsche', [1, 2]]

# %% [markdown]
# **Remove items from a list**
#
# Built in functions can be used to remove elements from a list
# * clear() - removes all the items from the list
# * remove(val) - removes the first occurance of the item from the list
# * pop(index) - the index parameter is optional. Removes the last elements of the list if no index is given. Otherwise, removes the element of the given index

# %% [markdown]
# **Using the pop(index) or pop() method**

# %%
cars = ['Bmw', 'Audi', 'Porsche',[1,2,3,5,7,8]]
cars.pop(4)
print(cars)
#cars[3].pop(1)
#print(cars)

# cars.pop(2)
# print(cars)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-28e8763db48c> in <module>
#       1 cars = ['Bmw', 'Audi', 'Porsche',[1,2,3,5,7,8]]
# ----> 2 cars.pop(4)
#       3 print(cars)
#       4 #cars[3].pop(1)
#       5 #print(cars)
#
# IndexError: pop index out of range

# %% [markdown]
# **Using the remove(value) method**

# %%
cars = ['Bmw' ,'Audi', 'Bmw','Porsche',[0,1,2]]

#cars.remove([0,1,2])
#print(cars)
cars.remove('Bmw')
cars.remove('Bmw')
print(cars)
# Out:
# ['Audi', 'Porsche', [0, 1, 2]]

# %% [markdown]
# **Using the del keyword**

# %%
cars = ['Bmw', 'Audi', 'Porsche']
del cars[0]
print(cars)

#del cars
#print(cars)
# Out:
# ['Audi', 'Porsche']

# %% [markdown]
# **Using the clear() method**

# %%
cars = ['Bmw', 'Audi', 'Porsche']
s = cars.copy()
cars.clear()
print(cars)
print(s)
# Out:
# []
# ['Bmw', 'Audi', 'Porsche']

# %% [markdown]
# **Copy a list**
#
# * Using the copy() method

# %%
cars = ['Bmw', 'Audi', 'Porsche']
cars2 = cars
cars[2] = 'Hello'
print(cars)
print(cars2)
# Out:
# ['Bmw', 'Audi', 'Hello']
# ['Bmw', 'Audi', 'Hello']

# %% [markdown]
# **List Slicing**
#
# list[start:end:step]
#
# * start(inclusive): specifies the starting index. If not provided, starts at 0.
#
# * end(exclusive): specifies the ending index. If not provided, ends at last index.
#
# * step(optional): specifies the increment
#
# * the return value will be a new list with the specified items

# %%
colors = ['Black', 'White', 'Red', 'Blue', 'Green', 'Purple', 'Yellow']

clr = colors[1:4]

print(clr) #Output will be: ['White', 'Red', 'Blue']

print(colors[:4]) 

print(colors[3:]) #Output will be: ['Blue', 'Green', 'Purple', 'Yellow']

print(colors[-4:-1]) #Output will be: ['Blue', 'Green', 'Purple']
# Out:
# ['White', 'Red', 'Blue']
# ['Black', 'White', 'Red', 'Blue']
# ['Blue', 'Green', 'Purple', 'Yellow']
# ['Blue', 'Green', 'Purple']

# %% [markdown]
# **Joining Two Lists**
#
# * Using the (+) operator

# %%
colors = ['red', 'blue', 'green']
fruits = ['Mango', 'Apple', 'Jackfruit']
new = colors + fruits
print(new)
# Out:
# ['red', 'blue', 'green', 'Mango', 'Apple', 'Jackfruit']

# %% [markdown]
# * Using extend() method

# %%
colors = ['red', 'blue', 'green']
fruits = ['Mango', 'Apple', 'Jackfruit']
colors.extend(fruits)
print(colors)
# Out:
# ['red', 'blue', 'green', 'Mango', 'Apple', 'Jackfruit']

# %% [markdown]
# **More functions of List**

# %% [markdown]
# **list.index(x)**
#
# Syntax: **list.index(element, start, end)**
#
# Parameters:
#
# **element** – The element whose lowest index will be returned.
#
# **start (Optional)** – The position from where the search begins. It is inclusive
#
# **end (Optional)** – The position from where the search ends. It is exclusive

# %%
colors = ['red', 'blue', 'green', 'blue red', 0 , 'red', 'blue','yellow' ]
print(colors.index('blue'))
print(colors.index('blue',1,7))
print(colors.index('blue',2,7))
# Out:
# 1
# 1
# 6

# %% [markdown]
# **list.count(x)** - Returns count of number of occurances of x in list

# %%
colors = ['red', 'blue', 'green', 'blue red', 0 , 'red' ]
print(colors.count('red'))
# Out:
# 2

# %% [markdown]
# **list.sort(reverse = ....)**
#
# By default, sort() doesn't require any extra parameters.
#
# However, reverse if optional.
#
# If True, the sorted list is reversed (or sorted in Descending order)

# %%
numbers = [1,3,4,6,7,2,8]
numbers.sort()
#print(numbers)
numbers.sort(reverse = True)
print(numbers)
# alphabet = ['a','c','g', 'a','4' ,'l', '2']
# alphabet.sort(reverse = False)
# print(alphabet)
# print(ord('4'))
# print(ord('2'))
# print(ord('a'))
# Out:
# [8, 7, 6, 4, 3, 2, 1]

# %% [markdown]
# **list.reverse()**
#
# It reverse the original list

# %%
alphabet = ['a','c','g', 'a','j','l','t']
alphabet.reverse()
print(alphabet)
# Out:
# ['t', 'l', 'j', 'a', 'g', 'c', 'a']

# %% [markdown]
# * max(list) - returns the maximum value in list
# * min(list) - returns the minimum value in list
# * sum(list) - returns the sum of values in list

# %%
val = [2,5,4,6,3,1,22,68,4]
print(max(val))
print(min(val))
print(sum(val))


#-----------------------
# Out:
# 68
# 1
# 115

# %%
# id() function returns an unique identifier (reference/location)
val = [1,2,4]
val2 = [4,5,6]
print(id(val))
print(id(val2))
val2 = val
print(id(val))
print(id(val2))
